# %% [markdown]
# #### Pandas stands for `Panel Data` used to analyse, clean and manipulating the data

# %% [markdown]
#      Group by Functionality
#      Flexible Rehsaping and Pivoting of Data Sets
#      Merging and Joining Data Sets
#
# These are the few advantages of Pandas

# %% [markdown]
# ##### Credation Of Data Frames using Pandas

# %%
import pandas as pd

# %%
data = {'Name': ['Ram', 'Lakshman', 'Sita', 'Hanuman', 'Bharath', 'Shatrughna'], 'Age' : [24,23,23,20,22,21]}

# %%
dataFrame = pd.DataFrame(data)
dataFrame
# Out:
#          Name  Age
# 0         Ram   24
# 1    Lakshman   23
# 2        Sita   23
# 3     Hanuman   20
# 4     Bharath   22
# 5  Shatrughna   21

# %%
# Adding a gender column to the existing data
dataFrame['Gender'] = ['Male', 'Male', 'Female', 'Male', 'Male', 'Male']
dataFrame
# Out:
#          Name  Age  Gender
# 0         Ram   24    Male
# 1    Lakshman   23    Male
# 2        Sita   23  Female
# 3     Hanuman   20    Male
# 4     Bharath   22    Male
# 5  Shatrughna   21    Male

# %%
# Loading the exisiting data
df =pd.read_csv(r"R:\Data Science and AI\Pandas\cars.csv")
df
# Out:
#     USCA   US United States    809  FALSE
# 0  ASPAC  AUS     Australia  731.0   True
# 1  ASPAC  JAP         Japan  588.0   True
# 2  ASPAC   IN         India   18.0   True
# 3  ASPAC   RU        Russia  200.0  False
# 4  LATAM  MOR       Morocco   70.0  False
# 5    AFR   EG         Egypt   45.0  False
# 6    EUR  ENG       England    NaN   True

# %% [markdown]
# Data Exploartion in Pandas

# %%
# Prting the first 3 columns
df.head(3)
# Out:
#     USCA   US United States    809  FALSE
# 0  ASPAC  AUS     Australia  731.0   True
# 1  ASPAC  JAP         Japan  588.0   True
# 2  ASPAC   IN         India   18.0   True

# %% [markdown]
# head() function prints the first few rows or mentioned number of rows

# %%
# Printing the last 3 rows
df.tail(3)
# Out:
#     USCA   US United States   809  FALSE
# 4  LATAM  MOR       Morocco  70.0  False
# 5    AFR   EG         Egypt  45.0  False
# 6    EUR  ENG       England   NaN   True

# %% [markdown]
# tail() function prints the last few rows or the mentioned number of rows

# %%
# Checking the data types of all columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   USCA           7 non-null      object
#  1   US             7 non-null      object
#  2   United States  7 non-null      object
#  3   809            6 non-null      float64
#  4   FALSE          7 non-null      bool
# dtypes: bool(1), float64(1), object(3)
# memory usage: 363.0+ bytes

# %% [markdown]
# info() function also gives the overview on no.of missing values

# %%
# Statistical Summary of the data
df.describe()
# Out:
#               809
# count    6.000000
# mean   275.333333
# std    307.409607
# min     18.000000
# 25%     51.250000
# 50%    135.000000
# 75%    491.000000
# max    731.000000

# %%
# Cheking the no.of null value
df.isnull().sum()
# Out:
# USCA             0
# US               0
# United States    0
# 809              1
# FALSE            0
# dtype: int64

# %%
# Skipping the first row (only when it is needed)
df = pd.read_csv(r"R:\Data Science and AI\Pandas\cars.csv", header=None)
df
# Out:
#        0    1              2      3      4
# 0   USCA   US  United States  809.0  False
# 1  ASPAC  AUS      Australia  731.0   True
# 2  ASPAC  JAP          Japan  588.0   True
# 3  ASPAC   IN          India   18.0   True
# 4  ASPAC   RU         Russia  200.0  False
# 5  LATAM  MOR        Morocco   70.0  False
# 6    AFR   EG          Egypt   45.0  False
# 7    EUR  ENG        England    NaN   True

# %%
# Changing the header names
df.columns
# Out:
# Index([0, 1, 2, 3, 4], dtype='int64')

# %%
df.columns = ['Country Code', 'Region' , 'Country', 'Car_Per_Capita', 'Drive_Right']
df
# Out:
#   Country Code Region        Country  Car_Per_Capita  Drive_Right
# 0         USCA     US  United States           809.0        False
# 1        ASPAC    AUS      Australia           731.0         True
# 2        ASPAC    JAP          Japan           588.0         True
# 3        ASPAC     IN          India            18.0         True
# 4        ASPAC     RU         Russia           200.0        False
# 5        LATAM    MOR        Morocco            70.0        False
# 6          AFR     EG          Egypt            45.0        False
# 7          EUR    ENG        England             NaN         True

# %%
# setting the first column as index
df = pd.read_csv(r"R:\Data Science and AI\Pandas\cars.csv", header=None, index_col=0)
df
# Out:
#          1              2      3      4
# 0
# USCA    US  United States  809.0  False
# ASPAC  AUS      Australia  731.0   True
# ASPAC  JAP          Japan  588.0   True
# ASPAC   IN          India   18.0   True
# ASPAC   RU         Russia  200.0  False
# LATAM  MOR        Morocco   70.0  False
# AFR     EG          Egypt   45.0  False
# EUR    ENG        England    NaN   True

# %%
# renaming the column after indexing
df.columns = ['Region', 'Country', 'Car_Per_Capita', 'Drive_Right']
df
# Out:
#       Region        Country  Car_Per_Capita  Drive_Right
# 0
# USCA      US  United States           809.0        False
# ASPAC    AUS      Australia           731.0         True
# ASPAC    JAP          Japan           588.0         True
# ASPAC     IN          India            18.0         True
# ASPAC     RU         Russia           200.0        False
# LATAM    MOR        Morocco            70.0        False
# AFR       EG          Egypt            45.0        False
# EUR      ENG        England             NaN         True

# %%
# Renaming the index column
df.index.name = 'Country Code'
df
# Out:
#              Region        Country  Car_Per_Capita  Drive_Right
# Country Code
# USCA             US  United States           809.0        False
# ASPAC           AUS      Australia           731.0         True
# ASPAC           JAP          Japan           588.0         True
# ASPAC            IN          India            18.0         True
# ASPAC            RU         Russia           200.0        False
# LATAM           MOR        Morocco            70.0        False
# AFR              EG          Egypt            45.0        False
# EUR             ENG        England             NaN         True

# %%
# Delete the index name
df.index.name = None
df
# Out:
#       Region        Country  Car_Per_Capita  Drive_Right
# USCA      US  United States           809.0        False
# ASPAC    AUS      Australia           731.0         True
# ASPAC    JAP          Japan           588.0         True
# ASPAC     IN          India            18.0         True
# ASPAC     RU         Russia           200.0        False
# LATAM    MOR        Morocco            70.0        False
# AFR       EG          Egypt            45.0        False
# EUR      ENG        England             NaN         True

# %%
# Writing the dataframe to csv
df.to_csv('cars_from_pandas.csv')

# %% [markdown]
# ##### Let's Work with another data

# %%
# Setting first two columns as index
df = pd.read_excel(r"R:\Data Science and AI\Pandas\sales.xlsx", index_col = (0,1))
df.head(15)
# Out:
#                                 No_of_Orders    Profit      Sales
# Market       Region
# Africa       Western Africa              251 -12901.51   78476.06
#              Southern Africa              85  11768.58   51319.50
#              North Africa                182  21643.08   86698.89
#              Eastern Africa              110   8013.04   44182.60
#              Central Africa              103  15606.30   61689.99
# Asia Pacific Western Asia                382 -16766.90  124312.24
#              Southern Asia               469  67998.76  351806.60
#              Southeastern Asia           533  20948.84  329751.38
#              Oceania                     646  54734.02  408002.98
#              Eastern Asia                414  72805.10  315390.77
#              Central Asia                 37  -2649.76    8190.74
# Europe       Western Europe              964  82091.27  656637.14
#              Southern Europe             338  18911.49  215703.93
# ...

# %%
# Displaying the first 3 rows
df.head(3)
# Out:
#                         No_of_Orders    Profit     Sales
# Market Region
# Africa Western Africa            251 -12901.51  78476.06
#        Southern Africa            85  11768.58  51319.50
#        North Africa              182  21643.08  86698.89

# %%
# Displaying the last 3 rows
df.tail(3)
# Out:
#                    No_of_Orders    Profit      Sales
# Market Region
# USCA   Eastern US           443  47462.04  264973.98
#        Central US           356  33697.43  170416.31
#        Canada                49   7246.62   26298.81

# %%
# Displaying the information on the data stored
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 23 entries, ('Africa', 'Western Africa') to ('USCA', 'Canada')
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   No_of_Orders  23 non-null     int64
#  1   Profit        23 non-null     float64
#  2   Sales         23 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 1.6+ KB

# %% [markdown]
# There are no missing values present in the data

# %%
# Displayhing the statistical information of the data
df.describe()
# Out:
#        No_of_Orders        Profit          Sales
# count     23.000000     23.000000      23.000000
# mean     366.478261  28859.944783  206285.108696
# std      246.590361  27701.193773  160589.886606
# min       37.000000 -16766.900000    8190.740000
# 25%      211.500000  12073.085000   82587.475000
# 50%      356.000000  20948.840000  170416.310000
# 75%      479.500000  45882.845000  290182.375000
# max      964.000000  82091.270000  656637.140000

# %% [markdown]
# ##### Plotting graphs using Matplot and Seaborn

# %%
import matplotlib.pyplot as plt, seaborn as sns

# %%
plt.boxplot([df['Sales'], df['Profit']])
plt.title('Boxplot of Sales and Profit')
plt.show()

# %% [markdown]
# ##### Indexing and Slicing

# %%
# Displaying the sales column
df['Sales']
# Out:
# Market        Region
# Africa        Western Africa        78476.06
#               Southern Africa       51319.50
#               North Africa          86698.89
#               Eastern Africa        44182.60
#               Central Africa        61689.99
# Asia Pacific  Western Asia         124312.24
#               Southern Asia        351806.60
#               Southeastern Asia    329751.38
#               Oceania              408002.98
#               Eastern Asia         315390.77
#               Central Asia           8190.74
# Europe        Western Europe       656637.14
#               Southern Europe      215703.93
#               Northern Europe      252969.09
#               Eastern Europe       108258.93
# LATAM         South America        210710.49
#               Central America      461670.28
#               Caribbean            116333.05
# USCA          Western US           251991.83
#               Southern US          148771.91
# ...

# %%
df[['Sales', 'Profit']]
# Out:
#                                     Sales    Profit
# Market       Region
# Africa       Western Africa      78476.06 -12901.51
#              Southern Africa     51319.50  11768.58
#              North Africa        86698.89  21643.08
#              Eastern Africa      44182.60   8013.04
#              Central Africa      61689.99  15606.30
# Asia Pacific Western Asia       124312.24 -16766.90
#              Southern Asia      351806.60  67998.76
#              Southeastern Asia  329751.38  20948.84
#              Oceania            408002.98  54734.02
#              Eastern Asia       315390.77  72805.10
#              Central Asia         8190.74  -2649.76
# Europe       Western Europe     656637.14  82091.27
#              Southern Europe    215703.93  18911.49
#              Northern Europe    252969.09  43237.44
#              Eastern Europe     108258.93  25050.69
# LATAM        South America      210710.49  12377.59
#              Central America    461670.28  74679.54
# ...

# %%
# Display the data for south asia
df = pd.read_excel(r"R:\Data Science and AI\Pandas\sales.xlsx", index_col = 0)
df.head(15)
# Out:
#                          Region  No_of_Orders    Profit      Sales
# Market
# Africa           Western Africa           251 -12901.51   78476.06
# Africa          Southern Africa            85  11768.58   51319.50
# Africa             North Africa           182  21643.08   86698.89
# Africa           Eastern Africa           110   8013.04   44182.60
# Africa           Central Africa           103  15606.30   61689.99
# Asia Pacific       Western Asia           382 -16766.90  124312.24
# Asia Pacific      Southern Asia           469  67998.76  351806.60
# Asia Pacific  Southeastern Asia           533  20948.84  329751.38
# Asia Pacific            Oceania           646  54734.02  408002.98
# Asia Pacific       Eastern Asia           414  72805.10  315390.77
# Asia Pacific       Central Asia            37  -2649.76    8190.74
# Europe           Western Europe           964  82091.27  656637.14
# Europe          Southern Europe           338  18911.49  215703.93
# ...

# %%
df.iloc[6]
# Out:
# Region          Southern Asia
# No_of_Orders              469
# Profit               67998.76
# Sales                351806.6
# Name: Asia Pacific, dtype: object

# %%
df.iloc[0::4, 2]
# Out:
# Market
# Africa         -12901.51
# Africa          15606.30
# Asia Pacific    54734.02
# Europe          18911.49
# LATAM           74679.54
# USCA            47462.04
# Name: Profit, dtype: float64

# %% [markdown]
# ##### Operations on Pandas

# %%
df_weather = pd.read_csv(r"R:\Data Science and AI\Pandas\weatherdata.csv")
df_weather.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed
# 0           W           44.0
# 1         WNW           44.0
# 2         WSW           46.0
# 3          NE           24.0
# 4           W           41.0

# %% [markdown]
# Data dictionary below:
#
# - Date: Date on which a data was recorded
# - Location: The location where the data was recorded
# - MinTemp: Minimum temperature on the day of recording data (in degrees Celsius)
# - MaxTemp: Maximum temperature on the day of recording data (in degrees Celsius)
# - Rainfall: Rainfall in mm
# - Evaporation: The so-called Class A pan evaporation (mm) in the 24 hours up to 9 AM
# - Sunshine: Number of hours of bright sunshine in the day
# - WindGustDir: Direction of the strongest gust of wind in the 24 hours up to midnight
# - WindGustSpeed: Speed (km/h) of the strongest gust of wind in the 24 hours up to midnight

# %% [markdown]
# Filtering

# %%
df_weather[df_weather['Sunshine']>4]
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 5939    2009-01-01    Cobar     17.9     35.2       0.0         12.0
# 5940    2009-01-02    Cobar     18.4     28.9       0.0         14.8
# 5941    2009-01-03    Cobar     15.5     34.1       0.0         12.6
# 5942    2009-01-04    Cobar     19.4     37.6       0.0         10.8
# 5943    2009-01-05    Cobar     21.9     38.4       0.0         11.4
# ...            ...      ...      ...      ...       ...          ...
# 139108  2017-06-20   Darwin     19.3     33.4       0.0          6.0
# 139109  2017-06-21   Darwin     21.2     32.6       0.0          7.6
# 139110  2017-06-22   Darwin     20.7     32.8       0.0          5.6
# 139111  2017-06-23   Darwin     19.5     31.8       0.0          6.2
# 139112  2017-06-24   Darwin     20.2     31.7       0.0          5.6
#
#         Sunshine WindGustDir  WindGustSpeed
# 5939        12.3         SSW           48.0
# 5940        13.0           S           37.0
# ...

# %% [markdown]
# The above data represents date on which sunshine was there for more then 4 hrs

# %%
df_weather[(df_weather['Sunshine']>4) & (df_weather['MaxTemp']>35)]
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 5939    2009-01-01    Cobar     17.9     35.2       0.0         12.0
# 5942    2009-01-04    Cobar     19.4     37.6       0.0         10.8
# 5943    2009-01-05    Cobar     21.9     38.4       0.0         11.4
# 5944    2009-01-06    Cobar     24.2     41.0       0.0         11.2
# 5948    2009-01-10    Cobar     19.0     35.5       0.0         12.0
# ...            ...      ...      ...      ...       ...          ...
# 138862  2016-10-17   Darwin     25.1     35.2       0.0          7.4
# 138879  2016-11-03   Darwin     24.4     35.5       0.0          7.8
# 138892  2016-11-16   Darwin     25.7     35.2       0.0          5.4
# 138905  2016-11-29   Darwin     25.8     35.1       0.8          4.8
# 138910  2016-12-04   Darwin     25.8     35.2       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed
# 5939        12.3         SSW           48.0
# 5942        10.6         NNE           46.0
# ...

# %% [markdown]
# The above data represents date on which sunshine was there for more then 4 hrs and high temp >35

# %% [markdown]
# ##### Creating New Columns

# %%
df_weather['Year'] = pd.DatetimeIndex(df_weather['Date']).year
df_weather
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed  Year
# 0            NaN           W           44.0  2008
# ...

# %% [markdown]
# The above code extracted the year from `Date` Column
